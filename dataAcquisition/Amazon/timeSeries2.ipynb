# %%
import pandas as pd
df = pd.read_excel('./AmazonSaleReport.xlsx', parse_dates=['Date'], index_col='Date')
df.sort_index(inplace=True)
df.head()
# Out:
#               Order ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146 2022-04-30                       Shipped     Amazon
# 3  403-9615377-8133951 2022-04-30                     Cancelled   Merchant
# 4  407-1069790-7240320 2022-04-30                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU       Category  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S            Set
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3      Amazon.in           Standard    J0341       J0341-DR-L  Western Dress
# 4      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
df_timeseries = df['Amount']

# transform date into datetime object
df_timeseries['Date'] = pd.to_datetime(df['Date'])
df_timeseries.head()
# Out:
# /var/folders/mw/2cx6x93d04g09y_zdvpb9vpc0000gn/T/ipykernel_39383/740530556.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_timeseries['Date'] = pd.to_datetime(df['Date'])
# 0    647.62
# 1     406.0
# 2     329.0
# 3    753.33
# 4     574.0
# Name: Amount, dtype: object

# %%
#sum the amount for each day
df_time_series = df.resample('D').sum()['Amount']

df_time_series.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 df['Date'] = pd.to_datetime(df['Date'])
#       6 #sum the amount for each day
# ----> 7 df_time_series = df.resample('D').sum()['Amount']
#       9 df_time_series.head()
#
# File ~/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/Uni/4/TFG/Proyecto/.venv/lib/python3.11/site-packages/pandas/core/generic.py:9771, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9768 else:
#    9769     convention = "start"
# -> 9771 return get_resampler(
#    9772     cast("Series | DataFrame", self),
#    9773     freq=rule,
#    9774     label=label,
#    9775     closed=closed,
#    9776     axis=axis,
#    9777     kind=kind,
#    9778     convention=convention,
#    9779     key=on,
#    9780     level=level,
#    9781     origin=origin,
# ...
